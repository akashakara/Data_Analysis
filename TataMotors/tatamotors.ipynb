# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/akashkumarsingh/Documents/Data Science/TataMotors/TATAMOTORs.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-06-22  102.349998  104.900002  101.000000  102.650002  102.650002
# 1  2020-06-23  103.000000  106.000000  101.900002  104.400002  104.400002
# 2  2020-06-24  105.250000  110.800003  104.199997  104.800003  104.800003
# 3  2020-06-25  103.849998  106.300003  101.650002  103.800003  103.800003
# 4  2020-06-26  105.400002  106.050003  100.349998  101.400002  101.400002
#
#         Volume
# 0   68545834.0
# 1   68638552.0
# 2  125457492.0
# 3   63198285.0
# 4   56327855.0

# %%
import matplotlib.pyplot as plt

# Settings for pretty nice plots
plt.style.use('fivethirtyeight')
plt.show()

# %%
df['Adj Close'].plot(figsize=(16,8),title='Adjusted Closing Price')
# Out:
# <AxesSubplot:title={'center':'Adjusted Closing Price'}>
